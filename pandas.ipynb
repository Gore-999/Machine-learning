# %% [markdown]
# <a href="https://colab.research.google.com/github/Gore-999/Machine-learning/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###PANDAS

# %%
  import pandas as pd

  data = {
      "cars": ["BMW", "Volvo", "Ford", "Benz","F1"],
      "models": ["2005", "2013", "2008", "2023","2010"],
      "passengers": ["4","6","4","4","1"]
  }
  data
# Out:
# {'cars': ['BMW', 'Volvo', 'Ford', 'Benz', 'F1'],
#  'models': ['2005', '2013', '2008', '2023', '2010'],
#  'passengers': ['4', '6', '4', '4', '1']}

# %%
# convert the data dictionary to dataframe
df = pd.DataFrame(data)
df
# Out:
#     cars models passengers
# 0    BMW   2005          4
# 1  Volvo   2013          6
# 2   Ford   2008          4
# 3   Benz   2023          4
# 4     F1   2010          1

# %%
df.to_csv("/content/drive/MyDrive/Colab Notebooks/college/car_data.CSV")

# %%
df = pd.read_csv("/content/car_data.CSV")
df
# Out:
#    Unnamed: 0   cars  models  passengers
# 0           0    BMW    2005           4
# 1           1  Volvo    2013           6
# 2           2   Ford    2008           4
# 3           3   Benz    2023           4
# 4           4     F1    2010           1

# %%
#create a dataframe with two features calories and duration.
import pandas as pd
data = {
    "calories": ["420","500","390"],
    "duration": ["50","40","45"]
}
data
# Out:
# {'calories': ['420', '500', '390'], 'duration': ['50', '40', '45']}

# %%
#convert the dictionary to dataframe
df = pd.DataFrame(data)
df
# Out:
#   calories duration
# 0      420       50
# 1      500       40
# 2      390       45
